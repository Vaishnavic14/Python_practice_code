# %% [markdown]
# # WITHOUT USING MATPLOTLIB WE WORK IMAGE WITH OPEN CV

# %%
import cv2 

myimg = cv2.imread(r'C:\Users\PC World\Downloads\watsapp.jpeg')

cv2.imshow('my image', myimg)

cv2.waitKey()
# Out:
# -1

# %%
type(myimg)
# Out:
# numpy.ndarray

# %%
wrong_img = cv2.imread(r'C:\Users\PC World\Downloads\app.jpeg')

# %%
type(wrong_img)
# Out:
# NoneType

# %% [markdown]
# - If img is not in that folder, then it'll not show any error while executing.
# - Never give you the error even you dont have any img in the folder.

# %%
import cv2 

myimg = cv2.imread(r'C:\Users\PC World\Downloads\watsapp.jpeg')

cv2.imshow('my image', myimg)

cv2.waitKey()
# Out:
# -1

# %%
import cv2 

myimg = cv2.imread(r'C:\Users\PC World\Downloads\watsapp.jpeg')
    while True:
        cv2.imshow('my image', myimg)
        
        # Wait for 1ms and check if 'Esc' (27) was pressed
        if cv2.waitKey(1) & 0xFF == 27:
            break
            
    # Move this OUTSIDE the while loop 
    cv2.destroyAllWindows()
