# %% [markdown]
# # Introduction to Opencv & Image Processing

# %%
#pip install opencv-python

# %%
import numpy as np 
import matplotlib.pyplot as plt
from PIL import Image
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread(r'C:\Users\PC World\OneDrive\Desktop\img1.jpeg')

# %%
img
# Out:
# array([[[ 58,  88,  83],
#         [183, 204, 201],
#         [223, 237, 235],
#         ...,
#         [  5,   7,  15],
#         [  5,   7,  15],
#         [  5,   7,  15]],
#
#        [[161, 182, 179],
#         [244, 255, 255],
#         [248, 255, 255],
#         ...,
#         [  5,   7,  15],
#         [  5,   7,  15],
#         [  5,   7,  15]],
#
#        [[231, 239, 238],
#         [243, 243, 243],
#         [254, 252, 252],
#         ...,
#         [  4,   6,  14],
#         [  4,   6,  14],
#         [  4,   6,  14]],
#
#        ...,
#
#        [[ 79, 112, 162],
#         [ 79, 111, 164],
#         [ 66,  97, 152],
#         ...,
#         [ 71,  89, 118],
#         [ 65,  83, 112],
#         [ 59,  77, 106]],
#
#        [[ 72, 106, 160],
#         [ 77, 111, 165],
#         [ 60,  94, 148],
#         ...,
#         [ 59,  77, 106],
#         [ 58,  76, 105],
#         [ 58,  76, 105]],
#
#        [[ 64,  96, 155],
#         [ 71, 104, 160],
#         [ 71, 105, 159],
# ...

# %%
type(img)
# Out:
# numpy.ndarray

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (183, 275, 3)

# %%
plt.imshow(img)
plt.show()

# %%
img
# Out:
# array([[[ 58,  88,  83],
#         [183, 204, 201],
#         [223, 237, 235],
#         ...,
#         [  5,   7,  15],
#         [  5,   7,  15],
#         [  5,   7,  15]],
#
#        [[161, 182, 179],
#         [244, 255, 255],
#         [248, 255, 255],
#         ...,
#         [  5,   7,  15],
#         [  5,   7,  15],
#         [  5,   7,  15]],
#
#        [[231, 239, 238],
#         [243, 243, 243],
#         [254, 252, 252],
#         ...,
#         [  4,   6,  14],
#         [  4,   6,  14],
#         [  4,   6,  14]],
#
#        ...,
#
#        [[ 79, 112, 162],
#         [ 79, 111, 164],
#         [ 66,  97, 152],
#         ...,
#         [ 71,  89, 118],
#         [ 65,  83, 112],
#         [ 59,  77, 106]],
#
#        [[ 72, 106, 160],
#         [ 77, 111, 165],
#         [ 60,  94, 148],
#         ...,
#         [ 59,  77, 106],
#         [ 58,  76, 105],
#         [ 58,  76, 105]],
#
#        [[ 64,  96, 155],
#         [ 71, 104, 160],
#         [ 71, 105, 159],
# ...

# %%
fix_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
fix_img.shape
# Out:
# (183, 275, 3)

# %%
plt.imshow(fix_img)
plt.show()

# %%
img_gray = cv2.imread(r'C:\Users\PC World\OneDrive\Desktop\img1.jpeg', cv2.IMREAD_GRAYSCALE)

# %%
img_gray.shape
# Out:
# (183, 275)

# %%
img_gray
# Out:
# array([[ 83, 201, 235, ...,   9,   9,   9],
#        [179, 255, 255, ...,   9,   9,   9],
#        [238, 243, 252, ...,   8,   8,   8],
#        ...,
#        [123, 123, 110, ...,  96,  90,  84],
#        [118, 123, 106, ...,  84,  83,  83],
#        [110, 117, 117, ...,  85,  91,  98]], dtype=uint8)

# %%
print(img_gray.min())
# Out:
# 0

# %%
print(img_gray.max())
# Out:
# 255

# %%
plt.imshow(img_gray)
plt.show()

# %%
plt.imshow(img_gray, cmap = 'gray')
plt.show()

# %%
plt.imshow(img_gray, cmap = 'magma')
plt.show()

# %%
plt.imshow(img_gray, cmap = 'Greens')
plt.show()

# %%
plt.imshow(img_gray, cmap = 'BuPu')
plt.show()

# %%
plt.imshow(img)
plt.show()

# %%
plt.imshow(fix_img)
plt.show()

# %%
fix_img.shape
# Out:
# (183, 275, 3)

# %%
fix_img_1 =cv2.resize(fix_img,(500,367))

# %%
fix_img_1.shape
# Out:
# (367, 500, 3)

# %%
w_ratio = 0.5
h_ratio = 0.5

# %%
fix_img_2 = cv2.resize(fix_img,(0,0), fix_img, w_ratio,h_ratio)

# %%
fix_img_2
# Out:
# array([[[180, 182, 162],
#         [237, 238, 225],
#         [175, 175, 151],
#         ...,
#         [ 20,  14,  11],
#         [ 15,   7,   5],
#         [ 15,   7,   5]],
#
#        [[245, 245, 245],
#         [249, 248, 248],
#         [238, 238, 221],
#         ...,
#         [ 19,  13,  10],
#         [ 14,   6,   4],
#         [ 14,   6,   4]],
#
#        [[254, 254, 251],
#         [254, 253, 251],
#         [227, 227, 207],
#         ...,
#         [ 17,  11,   8],
#         [ 12,   4,   2],
#         [ 12,   4,   2]],
#
#        ...,
#
#        [[149, 104,  70],
#         [157, 100,  70],
#         [172, 114,  84],
#         ...,
#         [115,  80,  61],
#         [107,  78,  60],
#         [102,  74,  56]],
#
#        [[163, 110,  77],
#         [158, 104,  71],
#         [172, 120,  87],
#         ...,
#         [115,  80,  61],
#         [110,  81,  63],
#         [106,  76,  58]],
#
#        [[158, 100,  68],
#         [173, 120,  86],
#         [172, 124,  88],
# ...

# %%
plt.imshow(fix_img_2)
plt.show()

# %%
img3 = cv2.flip(fix_img_2, 0)
plt.imshow(img3)
plt.show()

# %%
img3 = cv2.flip(fix_img_2, 1)
plt.imshow(img3)
plt.show()

# %%
cv2.imwrite('new genai img.jpeg', img3)
# Out:
# True

# %%
pwd
# Out:
# 'C:\\Users\\PC World\\Vaishnavich'
