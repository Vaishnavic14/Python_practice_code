# %% [markdown]
# # 3rd -- Python Datastructure
# - list
# - tuple
# - set
# - dict

# %%
l = []
l
# Out:
# []

# %%
type(l)
# Out:
# list

# %%
len(l)
# Out:
# 0

# %%
l
# Out:
# []

# %%
l.append(10)
l
# Out:
# [10]

# %%
l.append(20)
l
# Out:
# [10, 20]

# %%
l.append(30)
l.append(40)
l.append(50)
l
# Out:
# [10, 20, 30, 40, 50]

# %%
l1 = l.copy()
l1
# Out:
# [10, 20, 30, 40, 50]

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40, 50]
# [10, 20, 30, 40, 50]

# %%
l1.append('hi',1+2j,2.3,True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 l1.append('hi',1+2j,2.3,True)
#
# TypeError: list.append() takes exactly one argument (4 given)

# %%
l1
# Out:
# [10, 20, 30, 40, 50]

# %%
l1.append(2.3)
l1.append(2+3j)
l1.append(True)
l1.append('hi')
l1
# Out:
# [10, 20, 30, 40, 50, 2.3, (2+3j), True, 'hi']

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40, 50]
# [10, 20, 30, 40, 50, 2.3, (2+3j), True, 'hi']

# %%
print(len(l))
print(len(l1))
# Out:
# 5
# 9

# %%
l
# Out:
# [10, 20, 30, 40, 50]

# %%
l.append(10)
l
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
l3= [1,2,3,4,5,6,7,8,'hi','by', 1+2j, True]

# %%
l3
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 'hi', 'by', (1+2j), True]

# %%
l3.clear()
l3
# Out:
# []

# %%
del l3
l3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 del l3
# ----> 2 l3
#
# NameError: name 'l3' is not defined

# %%
l.count(20)
# Out:
# 1

# %%
l1.count(20)
# Out:
# 1

# %%
l1.count(True)
# Out:
# 1

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 2.3, (2+3j), True, 'hi']

# %%
l[:]
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
l[2:]
# Out:
# [30, 40, 50, 10]

# %%
l[::-1]
# Out:
# [10, 50, 40, 30, 20, 10]

# %%
l[:-1]
# Out:
# [10, 20, 30, 40, 50]

# %%
l[:::]
# Out:
#   Cell In[29], line 1
#     l[:::]
#         ^
# SyntaxError: invalid syntax

# %%
l
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 2.3, (2+3j), True, 'hi']

# %%
l1.index('hi')
# Out:
# 8

# %%
l1[8]
# Out:
# 'hi'

# %%
l[::2]
# Out:
# [10, 30, 50]

# %%
l[::3]
# Out:
# [10, 40]

# %%
l1[1:10:3]
# Out:
# [20, 50, True]

# %%
l
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
l[0]
# Out:
# 10

# %%
l[0]=100

# %%
l
# Out:
# [100, 20, 30, 40, 50, 10]

# %%
l[-1]=1000
l
# Out:
# [100, 20, 30, 40, 50, 1000]

# %%
l
# Out:
# [100, 20, 30, 40, 50, 1000]

# %%
l2=[]
l2
# Out:
# []

# %%
l2.extend(l1)
l2
# Out:
# [10, 20, 30, 40, 50, 2.3, (2+3j), True, 'hi']

# %%
l2.extend(l)
l2
# Out:
# [10, 20, 30, 40, 50, 2.3, (2+3j), True, 'hi', 100, 20, 30, 40, 50, 1000]

# %%
print(l)
print(l2)
print(l1)
# Out:
# [100, 20, 30, 40, 50, 1000]
# [10, 20, 30, 40, 50, 2.3, (2+3j), True, 'hi', 100, 20, 30, 40, 50, 1000]
# [10, 20, 30, 40, 50, 2.3, (2+3j), True, 'hi']

# %%
l.extend(l)(l2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 l.extend(l)(l2)
#
# TypeError: 'NoneType' object is not callable

# %%
l.index(0)
l
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 l.index(0)
#       2 l
#
# ValueError: 0 is not in list

# %%
l.index(100)
l
# Out:
# [100, 20, 30, 40, 50, 1000, 100, 20, 30, 40, 50, 1000]

# %%
l.index(20)
l
# Out:
# [100, 20, 30, 40, 50, 1000, 100, 20, 30, 40, 50, 1000]

# %%
l
# Out:
# [100, 20, 30, 40, 50, 1000, 100, 20, 30, 40, 50, 1000]

# %%
l.insert(2, 25)
l
# Out:
# [100, 20, 25, 30, 40, 50, 1000, 100, 20, 30, 40, 50, 1000]

# %%
l.insert(0,0)
l
# Out:
# [0, 100, 20, 25, 30, 40, 50, 1000, 100, 20, 30, 40, 50, 1000]

# %%
for i in (l):
  print(i)
# Out:
# 0
# 100
# 20
# 25
# 30
# 40
# 50
# 1000
# 100
# 20
# 30
# 40
# 50
# 1000

# %%
for i in enumerate(l):
    print(i)
# Out:
# (0, 0)
# (1, 100)
# (2, 20)
# (3, 25)
# (4, 30)
# (5, 40)
# (6, 50)
# (7, 1000)
# (8, 100)
# (9, 20)
# (10, 30)
# (11, 40)
# (12, 50)
# (13, 1000)

# %%
l
# Out:
# [0, 100, 20, 25, 30, 40, 50, 1000, 100, 20, 30, 40, 50, 1000]

# %%
l.pop()
l
# Out:
# [0, 100, 20, 25, 30, 40, 50, 1000, 100, 20, 30, 40, 50]

# %%
l.pop(0)
l
# Out:
# [100, 20, 25, 30, 40, 50, 1000, 100, 20, 30, 40, 50]

# %%
l.pop()
l
# Out:
# [100, 20, 25, 30, 40, 50, 1000, 100, 20, 30, 40]

# %%
l.pop()
l
# Out:
# [100, 20, 25, 30, 40, 50, 1000, 100, 20, 30]

# %%
l.append(10)
l
# Out:
# [100, 20, 25, 30, 40, 50, 1000, 100, 20, 30, 10]

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 2.3, (2+3j), True, 'hi']

# %%
l1.append(2.4),
l1.append(1+2j),
l1.append(True),
l1.append('Vaish')
l1
# Out:
# [10, 20, 30, 40, 50, 2.3, (2+3j), True, 'hi', 2.4, (1+2j), True, 'Vaish']

# %%
l1.remove(1+2j)
l1
# Out:
# [10, 20, 30, 40, 50, 2.3, (2+3j), True, 'hi', 2.4, True, 'Vaish']

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 2.3, (2+3j), True, 'hi', 2.4, True, 'Vaish']

# %%
l1.reverse()

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 2.3, (2+3j), True, 'hi', 2.4, True, 'Vaish']

# %%
l1[::-1]
# Out:
# ['Vaish', True, 2.4, 'hi', True, (2+3j), 2.3, 50, 40, 30, 20, 10]

# %%
l.sort()

# %%
l
# Out:
# [10, 20, 20, 25, 30, 30, 40, 50, 100, 100, 1000]

# %%
l3 = ['x','y','z']
l3.sort()

# %%
l3
# Out:
# ['x', 'y', 'z']

# %%
l2
# Out:
# [10, 20, 30, 40, 50, 2.3, (2+3j), True, 'hi', 100, 20, 30, 40, 50, 1000]

# %%
l2.sort(reverse=True)
l2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 l2.sort(reverse=True)
#       2 l2
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
l
# Out:
# [10, 20, 20, 25, 30, 30, 40, 50, 100, 100, 1000]

# %%
20 in l1
# Out:
# True

# %%
all(l)
# Out:
# True

# %%
any(l)
# Out:
# True

# %%
l
# Out:
# [10, 20, 20, 25, 30, 30, 40, 50, 100, 100, 1000]

# %%
l.append(0)
l
# Out:
# [10, 20, 20, 25, 30, 30, 40, 50, 100, 100, 1000, 0]

# %%
all(l)
# Out:
# False

# %%
any(l)
# Out:
# True

# %% [markdown]
# - list is completed.

# %% [markdown]
# # TUPLE

# %%
t=()

# %%
t1 = (10,20,30)
t1
# Out:
# (10, 20, 30)

# %%
type(t1)
# Out:
# tuple

# %%
icici = (12345678, 'cgf56787h', 2000)
icici
# Out:
# (12345678, 'cgf56787h', 2000)

# %%
icici.remove(2000)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 icici.remove(2000)
#
# AttributeError: 'tuple' object has no attribute 'remove'

# %%
icici[0]
# Out:
# 12345678

# %%
icici[0]= 9876543
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 icici[0]= 9876543
#
# TypeError: 'tuple' object does not support item assignment

# %%
t1
# Out:
# (10, 20, 30)

# %%
t1.count(10)
# Out:
# 1

# %%
t2 = (20,20)

# %%
t2
# Out:
# (20, 20)

# %%
t1.index(10)
# Out:
# 0

# %%
t2.count(20)
# Out:
# 2

# %%
t2.count(10)
# Out:
# 0

# %%
t1
# Out:
# (10, 20, 30)

# %%
for i in t1:
  print(t1)
# Out:
# (10, 20, 30)
# (10, 20, 30)
# (10, 20, 30)

# %%
for i in t2:
  print(t2)
# Out:
# (20, 20)
# (20, 20)

# %%
t2 = ([1,2,3,],3,True,1+2j,'Vaish')
t2
# Out:
# ([1, 2, 3], 3, True, (1+2j), 'Vaish')

# %% [markdown]
# # list & tuple is completed
