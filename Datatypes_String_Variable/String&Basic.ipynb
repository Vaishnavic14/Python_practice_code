# %% [markdown]
# # Introduction (T1)

# %%
print(3 + 2) 
print(3 - 2)   
print(3 * 2)   
print(3 / 2)   
print(3 ** 2)  
print(3 % 2)   
print(3 // 2)
# Out:
# 5
# 1
# 6
# 1.5
# 9
# 1
# 1

# %%
print(type(10))                  
print(type(3.14))                
print(type(1 + 3j))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
print(type('VaishnaviChandore'))   
print(type([1, 2, 3]))            
print(type({'name':'Vaishnavi'}))
# Out:
# <class 'str'>
# <class 'list'>
# <class 'dict'>

# %%
print(type({9.8, 3.14, 2.7}))    
print(type((9.8, 3.14, 2.7)))    
print(type(3 == 3))              
print(type(3 >= 3))
# Out:
# <class 'set'>
# <class 'tuple'>
# <class 'bool'>
# <class 'bool'>

# %% [markdown]
# # String (T2)

# %%
letter = 'P' 
print(letter)               
print(len(letter))
# Out:
# P
# 1

# %%
greeting = 'Hello, World!'  
print(greeting)            
print(len(greeting))
# Out:
# Hello, World!
# 13

# %%
sentence = "The best adventures begin when expectation is abandoned and the heart is finally listening."
print(sentence)
# Out:
# The best adventures begin when expectation is abandoned and the heart is finally listening.

# %%
multiline_string = '''I am Final year Student.
Persuing B.tech Degree in Computer Engineering.
Currently I'm Learning python.'''
print(multiline_string)
# Out:
# I am Final year Student.
# Persuing B.tech Degree in Computer Engineering.
# Currently I'm Learning python.

# %%
multiline_string = """I am Final year Student.
Persuing B.tech Degree in Computer Engineering.
Currently I'm Learning python."""
print(multiline_string)
# Out:
# I am Final year Student.
# Persuing B.tech Degree in Computer Engineering.
# Currently I'm Learning python.

# %% [markdown]
# # String Concatenation

# %%
first_name = 'Vaishnavi'
last_name = 'Chandore'
space = ' '
full_name = first_name  +  space + last_name
print(full_name)
# Out:
# Vaishnavi Chandore

# %%
print(len(first_name)) 
print(len(last_name))
# Out:
# 9
# 8

# %%
print(len(first_name) > len(last_name)) 
print(len(full_name))
# Out:
# True
# 18

# %%
language = 'Python'
a,b,c,d,e,f = language
print(a) 
print(b) 
print(c) 
print(d) 
print(e) 
print(f)
# Out:
# P
# y
# t
# h
# o
# n

# %% [markdown]
# # Accessing characters in strings by index

# %%
language = 'Python'
first_letter = language[0]
print(first_letter)
# Out:
# P

# %%
second_letter = language[1]
print(second_letter)
# Out:
# y

# %%
last_index = len(language) - 1
last_letter = language[last_index]
print(last_letter)
# Out:
# n

# %%
language = 'Python'
last_letter = language[-1]
print(last_letter) 
second_last = language[-2]
print(second_last)
# Out:
# n
# o

# %% [markdown]
# # Slicing

# %%
language = 'Python'
first_three = language[0:3] 
last_three = language[3:6]
print(last_three)
# Out:
# hon

# %%
last_three = language[-3:]
print(last_three)
# Out:
# hon

# %%
last_three = language[3:]
print(last_three)
# Out:
# hon

# %%
anguage = 'Python'
pto = language[0:6:2] 
print(pto)
# Out:
# Pto

# %%
print('I hope every one enjoying the python challenge.\nDo you ?')
# Out:
# I hope every one enjoying the python challenge.
# Do you ?

# %%
print('Days\tTopics\tExercises')
# Out:
# Days	Topics	Exercises

# %%
print('Day 1\t3\t5')
# Out:
# Day 1	3	5

# %%
print('This is a back slash  symbol (\\)')
# Out:
# This is a back slash  symbol (\)

# %% [markdown]
# ## String Methods
# # capitalize(): Converts the first character the string to Capital Letter

# %%
challenge = 'thirty days of python'
print(challenge.capitalize())
# Out:
# Thirty days of python

# %%
challenge = 'thirty days of python'
print(challenge.count('y')) 
print(challenge.count('y', 7, 14)) 
print(challenge.count('th'))
# Out:
# 3
# 1
# 2

# %%
challenge = 'thirty days of python'
print(challenge.endswith('on'))  
print(challenge.endswith('tion'))
# Out:
# True
# False

# %%
challenge = 'thirty\tdays\tof\tpython'
print(challenge.expandtabs())  
print(challenge.expandtabs(10))
# Out:
# thirty  days    of      python
# thirty    days      of        python

# %%
challenge = 'thirty days of python'
print(challenge.find('y')) 
print(challenge.find('th'))
# Out:
# 5
# 0

# %%
first_name = 'Nick'
last_name = 'Chrcho'
job = 'Student'
country = 'Germany'
sentence = 'I am {} {}. I am a {}. I live in {}.'.format(first_name, last_name, job, country)
print(sentence)
# Out:
# I am Nick Chrcho. I am a Student. I live in Germany.

# %%
radius = 10
pi = 3.14
area = pi 
result = 'The area of circle with {} is {}'.format(str(radius), str(area))
print(result)
# Out:
# The area of circle with 10 is 3.14

# %%
challenge = 'thirty days of python'
print(challenge.find('y')) 
print(challenge.find('th'))
# Out:
# 5
# 0

# %%
challenge = 'ThirtyDaysPython'
print(challenge.isalnum())
# Out:
# True

# %%
challenge = '30DaysPython'
print(challenge.isalnum())
# Out:
# True

# %%
challenge = 'thirty days of python'
print(challenge.isalnum())
# Out:
# False

# %%
challenge = 'thirty days of python 2019'
print(challenge.isalnum())
# Out:
# False

# %%
challenge = 'thirty days of python'
print(challenge.isalpha()) 
num = '123'
print(num.isalpha())
# Out:
# False
# False

# %%
challenge = 'thirty days of python'
print(challenge.find('y')) 
print(challenge.find('th'))
# Out:
# 5
# 0

# %%
challenge = 'Thirty'
print(challenge.isdigit())
# Out:
# False

# %%
challenge = '30'
print(challenge.digit())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[53], line 2
#       1 challenge = '30'
# ----> 2 print(challenge.digit())
#
# AttributeError: 'str' object has no attribute 'digit'

# %%
num = '10'
print(num.isdecimal()) 
num = '10.5'
print(num.isdecimal())
# Out:
# True
# False

# %%
challenge = '30DaysOfPython'
print(challenge.isidentifier()) 
challenge = 'thirty_days_of_python'
print(challenge.isidentifier())
# Out:
# False
# True

# %%
challenge = 'thirty days of python'
print(challenge.islower()) 
challenge = 'Thirty days of python'
print(challenge.islower())
# Out:
# True
# False

# %%
challenge = 'thirty days of python'
print(challenge.isupper()) 
challenge = 'THIRTY DAYS OF PYTHON'
print(challenge.isupper())
# Out:
# False
# True

# %%
num = '10'
print(num.isnumeric())      
print('ten'.isnumeric())
# Out:
# True
# False

# %%
web_tech = ['HTML', 'CSS', 'JavaScript', 'React']
result = '#, '.join(web_tech)
print(result)
# Out:
# HTML#, CSS#, JavaScript#, React

# %%
challenge = ' thirty days of python '
print(challenge.strip('y'))
# Out:
#  thirty days of python

# %%
challenge = 'thirty days of python'
print(challenge.replace('python', 'coding'))
# Out:
# thirty days of coding

# %%
challenge = 'thirty days of python'
print(challenge.split())
# Out:
# ['thirty', 'days', 'of', 'python']

# %%
challenge = 'thirty days of python'
print(challenge.title())
# Out:
# Thirty Days Of Python

# %%
challenge = 'thirty days of python'
print(challenge.swapcase())
# Out:
# THIRTY DAYS OF PYTHON

# %%
challenge = 'Thirty Days Of Python'
print(challenge.swapcase())
# Out:
# tHIRTY dAYS oF pYTHON

# %%
challenge = 'thirty days of python'
print(challenge.startswith('thirty'))
# Out:
# True

# %%
challenge = '30 days of python'
print(challenge.startswith('thirty'))
# Out:
# False
