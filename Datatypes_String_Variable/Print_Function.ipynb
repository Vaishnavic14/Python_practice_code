# %%
a = 10
b = 12
a
b
# Out:
# 12

# %%
a = 10
b = 20
print(a)
print(b)
# Out:
# 10
# 20

# %%
print(10)
print(20)
print(10,20)
print(10,20,'python')
# Out:
# 10
# 20
# 10 20
# 10 20 python

# %%
num1 = 10
num2 = 20
add= num1+num2
print(add)
# Out:
# 30

# %%
num1 = 10
num2 = 20
add= num1+num2
print('the sum of', num1, 'and', num2 ,'is', add)
# Out:
# the sum of 10 and 20 is 30

# %%
name='Python'
age=20
city='hyd'
print('Hello my name is',name , 'I am',age,'years','I am from',city)
# Out:
# Hello my name is Python I am 20 years I am from hyd

# %%
num1 = 20
num2 = 30
add= num1+num2
print('The sum of {} and {} is {}'.format(num1,num2,add))
# Out:
# The sum of 20 and 30 is 50

# %%
name = 'Vaish'
age = 19
city = 'hyd'
print('My name is {} I am {} years and I am from {}'.format(name,age,city))
# Out:
# My name is Vaish I am 19 years and I am from hyd

# %%
num1 = 26
num2 = 34
num3 = 45
avg1 = (num1+num2+num3)/3
avg2 = round((num1+num2+num3)/3,2)
print('The average of {},{} and {} is {} or {}'.format(num1,num2,num3,avg1,avg2)
# Out:
#   Cell In[11], line 6
#     print('The average of {},{} and {} is {} or {}'.format(num1,num2,num3,avg1,avg2)
#                                                                                     ^
# _IncompleteInputError: incomplete input

# %%
num1 = 26
num2 = 34
num3 = 45
avg1 = (num1+num2+num3)/3
avg2 = round((num1+num2+num3)/3,2)
print('The average of {},{} and {} is {} or {}'.format(num1,num2,num3,avg1,avg2))
# Out:
# The average of 26,34 and 45 is 35.0 or 35.0

# %%
num1 = 20
num2 = 30
add = num1+num2
print(f'The sum of {num1} and {num2} is {add}')
# Out:
# The sum of 20 and 30 is 50

# %%
name = 'Yash'
age = 33
city = 'Ngp'
print(f'I am {name}, my age is {age} years and I am from {city}')
# Out:
# I am Yash, my age is 33 years and I am from Ngp

# %%
print('hello')
print('good morning')
# Out:
# hello
# good morning

# %%
print('hello' , end =' ')
print ('good morning')
# Out:
# hello good morning

# %%
print('Hello')
print('Good Morning')
# Out:
# Hello
# Good Morning

# %%
print('hello','hi','how','are','you',sep = '*')
# Out:
# hello*hi*how*are*you

# %%
print('hello','hi','how','are','you',sep = '')
# Out:
# hellohihowareyou

# %%
print('Hello','hi','how','are','you',sep = ' ')
# Out:
# Hello hi how are you

# %%
print(3,sep = '.')
# Out:
# 3

# %%
print(3,'.')
# Out:
# 3 .

# %%
print(3,'.',sep = '')
# Out:
# 3.

# %%
print(7,'.', sep = '')
# Out:
# 7.
