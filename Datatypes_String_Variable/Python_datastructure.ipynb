# %% [markdown]
# # 3rd -- Python Datastructure
# - list
# - tuple
# - set
# - dict

# %%
l = []
l
# Out:
# []

# %%
type(l)
# Out:
# list

# %%
len(l)
# Out:
# 0

# %%
l
# Out:
# []

# %%
l.append(10)
l
# Out:
# [10]

# %%
l.append(20)
l
# Out:
# [10, 20]

# %%
l.append(30)
l.append(40)
l.append(50)
l
# Out:
# [10, 20, 30, 40, 50]

# %%
l1 = l.copy()
l1
# Out:
# [10, 20, 30, 40, 50]

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40, 50]
# [10, 20, 30, 40, 50]

# %%
l1.append('hi',1+2j,2.3,True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 l1.append('hi',1+2j,2.3,True)
#
# TypeError: list.append() takes exactly one argument (4 given)

# %%
l1
# Out:
# [10, 20, 30, 40, 50]

# %%
l1.append(2.3)
l1.append(2+3j)
l1.append(True)
l1.append('hi')
l1
# Out:
# [10,
#  20,
#  30,
#  40,
#  50,
#  2.3,
#  (2+3j),
#  True,
#  'hi',
#  2.3,
#  (2+3j),
#  True,
#  'hi',
#  2.3,
#  (2+3j),
#  True,
#  'hi',
#  2.3,
#  (2+3j),
#  True,
#  'hi',
#  2.3,
#  (2+3j),
#  True,
#  'hi']

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40, 50]
# [10, 20, 30, 40, 50, 2.3, (2+3j), True, 'hi', 2.3, (2+3j), True, 'hi', 2.3, (2+3j), True, 'hi', 2.3, (2+3j), True, 'hi', 2.3, (2+3j), True, 'hi']

# %%
print(len(l))
print(len(l1))
# Out:
# 5
# 25

# %%
l
# Out:
# [10, 20, 30, 40, 50]

# %%
l.append(10)
l
# Out:
# [10, 20, 30, 40, 50, 10, 10]

# %%
l3= [1,2,3,4,5,6,7,8,'hi','by', 1+2j, True]

# %%
l3
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 'hi', 'by', (1+2j), True]

# %%
l3.clear()
l3
# Out:
# []

# %%
del l3
l3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 del l3
#       2 l3
#
# NameError: name 'l3' is not defined

# %%
l.count(20)
# Out:
# 1

# %%
l1.count(20)
# Out:
# 1

# %%
l1.count(True)
# Out:
# 5

# %%
l1
# Out:
# [10,
#  20,
#  30,
#  40,
#  50,
#  2.3,
#  (2+3j),
#  True,
#  'hi',
#  2.3,
#  (2+3j),
#  True,
#  'hi',
#  2.3,
#  (2+3j),
#  True,
#  'hi',
#  2.3,
#  (2+3j),
#  True,
#  'hi',
#  2.3,
#  (2+3j),
#  True,
#  'hi']

# %%
l[:]
# Out:
# [10, 20, 30, 40, 50, 10, 10]

# %%
l[2:]
# Out:
# [30, 40, 50, 10, 10]

# %%
l[::-1]
# Out:
# [10, 10, 50, 40, 30, 20, 10]

# %%
l[:-1]
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
l[:::]
# Out:
#   Cell In[38], line 1
#     l[:::]
#         ^
# SyntaxError: invalid syntax

# %%
l
# Out:
# [10, 20, 30, 40, 50, 10, 10]

# %%
l1
# Out:
# [10,
#  20,
#  30,
#  40,
#  50,
#  2.3,
#  (2+3j),
#  True,
#  'hi',
#  2.3,
#  (2+3j),
#  True,
#  'hi',
#  2.3,
#  (2+3j),
#  True,
#  'hi',
#  2.3,
#  (2+3j),
#  True,
#  'hi',
#  2.3,
#  (2+3j),
#  True,
#  'hi']

# %%
l1.index('hi')
# Out:
# 8

# %%
l1[8]
# Out:
# 'hi'

# %%
l[::2]
# Out:
# [10, 30, 50, 10]

# %%
l[::3]
# Out:
# [10, 40, 10]

# %%
l1[1:10:3]
# Out:
# [20, 50, True]
