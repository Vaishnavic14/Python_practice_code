# %% [markdown]
# # (1st Dec) Python data type

# %%
i = 57
i
# Out:
# 57

# %%
type(i)
# Out:
# int

# %%
f = 110.67
f
# Out:
# 110.67

# %%
type(f)
# Out:
# float

# %%
f1 = 1e0
f1
# Out:
# 1.0

# %%
f2 = 1e1
f2
# Out:
# 10.0

# %%
type(f2)
# Out:
# float

# %%
f3 = 2.3e3
f3
# Out:
# 2300.0

# %%
f4 = 5.4e5
f4
# Out:
# 540000.0

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
b = True
b
# Out:
# True

# %%
b = True
b1 = False 
b + b1
# Out:
# 1

# %%
print(b+b1)
print(b-b1)
print(b*b1)
# Out:
# 1
# 1
# 0

# %%
False/True
# Out:
# 0.0

# %%
False // True
# Out:
# 0

# %%
a = 1 + 2j  # syntax= a + bj
a
# Out:
# (1+2j)

# %% [markdown]
# # Complex

# %%
c =(10 + 20j)
c
# Out:
# (10+20j)

# %%
type(c)
# Out:
# complex

# %%
c.real
# Out:
# 10.0

# %%
c.imag
# Out:
# 20.0

# %%
c1 = 30 + 4.5j
c1
# Out:
# (30+4.5j)

# %%
c2 = 4.4 +20j
c2
# Out:
# (4.4+20j)

# %%
c1+c2
# Out:
# (34.4+24.5j)

# %% [markdown]
# # string

# %%
s = 'vaishnavi'
s
# Out:
# 'vaishnavi'

# %%
type(s)
# Out:
# str

# %%
s
# Out:
# 'vaishnavi'

# %%
s[0]
# Out:
# 'v'

# %%
s[-3]
# Out:
# 'a'

# %%
s
# Out:
# 'vaishnavi'

# %%
s[2:6]
# Out:
# 'ishn'

# %%
s[2:8:4] #forward indexing
# Out:
# 'ia'

# %%
s[-7]
# Out:
# 'i'

# %%
s[-1:-6:-1]
# Out:
# 'ivanh'

# %%
movie = "The film introduces the story of Rocky, a boy born into poverty who, driven by his dying mother's wish to be the richest and most powerful man, rises to become a high-ranking mercenary in Mumbai. His quest for power leads him to infiltrate the Kolar Gold Fields (KGF), a tyrannical slave labor camp ruled by the ruthless Suryavardhan and his son, Garuda, with the ultimate goal of assassinating Garuda."
movie
# Out:
# "The film introduces the story of Rocky, a boy born into poverty who, driven by his dying mother's wish to be the richest and most powerful man, rises to become a high-ranking mercenary in Mumbai. His quest for power leads him to infiltrate the Kolar Gold Fields (KGF), a tyrannical slave labor camp ruled by the ruthless Suryavardhan and his son, Garuda, with the ultimate goal of assassinating Garuda."

# %% [markdown]
# # Python Data Type Completed Today
