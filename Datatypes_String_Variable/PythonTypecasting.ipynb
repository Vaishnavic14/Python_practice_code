# %% [markdown]
# # 2nd typecasting

# %%
int(100)
# Out:
# 100

# %%
int(100.7)
# Out:
# 100

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
int("10")
# Out:
# 10

# %%
int("ten")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 int("ten")
#
# ValueError: invalid literal for int() with base 10: 'ten'

# %%
float(10.6)
# Out:
# 10.6

# %%
float(10)
# Out:
# 10.0

# %%
float(True)
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
float("10.8")
# Out:
# 10.8

# %%
float('10.8','40.8')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 float('10.8','40.8')
#
# TypeError: float expected at most 1 argument, got 2

# %%
float("ten")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 float("ten")
#
# ValueError: could not convert string to float: 'ten'

# %% [markdown]
# - we can type cast from other datatypes to int except 2 string parameter & text string.
# - we can type cast from other datatypes to float except 2 string parameter & text string.

# %%
complex(10)
# Out:
# (10+0j)

# %%
complex(10,20)
# Out:
# (10+20j)

# %%
complex('10')
# Out:
# (10+0j)

# %%
complex(10.5,33.33)
# Out:
# (10.5+33.33j)

# %%
complex(False,True)
# Out:
# 1j

# %%
complex(True,True)
# Out:
# (1+1j)

# %%
complex(False,True)
# Out:
# 1j

# %%
complex('10',15)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 complex('10',15)
#
# TypeError: complex() can't take second arg if first is a string

# %%
complex(10,'15')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 complex(10,'15')
#
# TypeError: complex() second arg can't be a string

# %%
complex('10','15')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 complex('10','15')
#
# TypeError: complex() can't take second arg if first is a string

# %%
complex('15')
# Out:
# (15+0j)

# %%
complex(int('10'),int('15'))
# Out:
# (10+15j)

# %% [markdown]
# - we can type cast from other datatypes to complex except 2 string parameter & text string.

# %%
print (str(2))
# Out:
# 2

# %%
str(2.3)
# Out:
# '2.3'

# %%
str(True)
# Out:
# 'True'

# %%
str(1+2j)
# Out:
# '(1+2j)'

# %% [markdown]
# - we can type cast from other datatypes to string no issue at all.

# %%
bool(10)
# Out:
# True

# %%
bool(2.3)
# Out:
# True

# %%
bool()
# Out:
# False

# %%
bool(0)
# Out:
# False

# %%
bool(1+2j)
# Out:
# True

# %%
bool("vital")
# Out:
# True

# %% [markdown]
# - we can type cast from other datatypes to bool no issue at all.
