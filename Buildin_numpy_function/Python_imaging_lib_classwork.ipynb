# %%
#  import matplotlib.python as pil

# %%
from PIL import Image

# %%
# pip install pillow

# %%
horse_image = Image.open(r'C:\Users\PC World\OneDrive\Desktop\images.jpg')
horse_image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=612x406>

# %%
type(horse_image)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
import numpy as np

# %%
horse_arr = np.asarray(horse_image)
(horse_arr)
# Out:
# array([[[122, 123, 128],
#         [123, 124, 129],
#         [124, 125, 130],
#         ...,
#         [170, 170, 170],
#         [170, 170, 170],
#         [170, 170, 170]],
#
#        [[121, 122, 127],
#         [122, 123, 128],
#         [123, 124, 129],
#         ...,
#         [170, 170, 170],
#         [170, 170, 170],
#         [170, 170, 170]],
#
#        [[120, 121, 126],
#         [120, 121, 126],
#         [121, 122, 127],
#         ...,
#         [169, 169, 169],
#         [169, 169, 169],
#         [169, 169, 169]],
#
#        ...,
#
#        [[129, 112,  58],
#         [120, 104,  52],
#         [106,  94,  44],
#         ...,
#         [154, 133,  78],
#         [153, 132,  77],
#         [154, 133,  78]],
#
#        [[122, 107,  52],
#         [119, 103,  52],
#         [115,  99,  50],
#         ...,
#         [150, 129,  72],
#         [150, 129,  72],
#         [151, 130,  73]],
#
#        [[117, 101,  49],
#         [119, 103,  52],
#         [122, 104,  56],
# ...

# %%
print(horse_arr)
# Out:
# [[[122 123 128]
#   [123 124 129]
#   [124 125 130]
#   ...
#   [170 170 170]
#   [170 170 170]
#   [170 170 170]]
#
#  [[121 122 127]
#   [122 123 128]
#   [123 124 129]
#   ...
#   [170 170 170]
#   [170 170 170]
#   [170 170 170]]
#
#  [[120 121 126]
#   [120 121 126]
#   [121 122 127]
#   ...
#   [169 169 169]
#   [169 169 169]
#   [169 169 169]]
#
#  ...
#
#  [[129 112  58]
#   [120 104  52]
#   [106  94  44]
#   ...
#   [154 133  78]
#   [153 132  77]
#   [154 133  78]]
#
#  [[122 107  52]
#   [119 103  52]
#   [115  99  50]
#   ...
#   [150 129  72]
#   [150 129  72]
#   [151 130  73]]
#
#  [[117 101  49]
#   [119 103  52]
#   [122 104  56]
#   ...
#   [151 132  74]
#   [150 131  73]
#   [152 133  75]]]

# %%
type(horse_arr)
# Out:
# numpy.ndarray

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(horse_image)

# %%
horse_arr.shape
# Out:
# (406, 612, 3)

# %%
plt.imshow(horse_image, cmap='BuPu')

# %%
plt.imshow(horse_arr[:,:,0], cmap='Greys')

# %%
plt.imshow(horse_arr[:,:,2], cmap='BuPu')

# %%
plt.imshow(horse_arr[:,:,0], cmap='Accent')

# %%
plt.imshow(horse_arr[:,:,0], cmap='GnBu')

# %%
plt.imshow(horse_arr[:,:,0], cmap='Oranges')

# %%
plt.imshow(horse_arr[:,:,0], cmap='RdBu')
